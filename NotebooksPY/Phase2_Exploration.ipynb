# %% [markdown]
# Empezamos la fase 2, solo para explorar el raw data set

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/ecommerce_raw_dataset.csv')

# Basic shape
print(df.shape)          # rows, columns
print(df.dtypes)         # column types
print(df.head(10))       # first 10 rows

# Missing values
print(df.isnull().sum())
# Basic stats
print(df.describe())
# Out:
# (1545, 19)
# order_id            object
# customer_id         object
# customer_name       object
# customer_email      object
# age                float64
# gender              object
# country             object
# order_date          object
# product_id          object
# product_name        object
# category            object
# quantity             int64
# unit_price         float64
# discount_pct         int64
# total_amount       float64
# payment_method      object
# shipping_method     object
# order_status        object
# rating             float64
# dtype: object
#     order_id customer_id    customer_name               customer_email   age  \
# 0  ORD-01496   CUST-0189     Arthur Ellis       fgutierrez@example.net  64.0
# 1  ORD-00544   CUST-0275    Michael Green                          NaN  31.0
# 2  ORD-01269   CUST-0229  Kimberly Dudley                          NaN  30.0
# 3  ORD-00529   CUST-0115      Anna Reilly         robert33@example.org  60.0
# ...

# %% [markdown]
# Como se puede observar, tenemos missing values en varias filas de rating, customer email, age, shipping method, order_status
